# %% [markdown]
# <a id="CGAN"><h1>Import Header</h1></a>

# %%
from google.colab import drive 
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive/PhD/Development/code/Current/EVAGAN
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/PhD/Development/code/Current/EVAGAN

# %%
# !pip install smote_variants
# Out:
# Collecting smote_variants
#   Downloading smote_variants-0.4.0-py3-none-any.whl (134 kB)
#      |████████████████████████████████| 134 kB 4.3 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from smote_variants) (1.1.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from smote_variants) (0.22.2.post1)
# Collecting minisom
#   Downloading MiniSom-2.2.9.tar.gz (8.1 kB)
# Collecting statistics
#   Downloading statistics-1.0.3.5.tar.gz (8.3 kB)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.7/dist-packages (from smote_variants) (2.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from smote_variants) (1.0.1)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from smote_variants) (1.19.5)
# Requirement already satisfied: mkl in /usr/local/lib/python3.7/dist-packages (from smote_variants) (2019.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from smote_variants) (1.4.1)
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (from smote_variants) (2.4.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras->smote_variants) (3.13)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras->smote_variants) (3.1.0)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras->smote_variants) (1.5.2)
# Requirement already satisfied: intel-openmp in /usr/local/lib/python3.7/dist-packages (from mkl->smote_variants) (2021.3.0)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.7/dist-packages (from pandas->smote_variants) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->smote_variants) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->smote_variants) (1.15.0)
# Requirement already satisfied: docutils>=0.3 in /usr/local/lib/python3.7/dist-packages (from statistics->smote_variants) (0.17.1)
# Requirement already satisfied: protobuf>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (3.17.3)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (2.5.0.dev2021032900)
# Requirement already satisfied: termcolor~=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (1.1.0)
# Requirement already satisfied: wrapt~=1.12.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (1.12.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (3.7.4.3)
# Requirement already satisfied: tensorboard~=2.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (2.5.0)
# Requirement already satisfied: google-pasta~=0.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (0.2.0)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (1.1.2)
# Requirement already satisfied: gast==0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (0.4.0)
# Requirement already satisfied: grpcio~=1.34.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (1.34.1)
# Requirement already satisfied: wheel~=0.35 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (0.37.0)
# Requirement already satisfied: absl-py~=0.10 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (0.12.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (2.5.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (1.12)
# Requirement already satisfied: astunparse~=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow->smote_variants) (1.6.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->smote_variants) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->smote_variants) (0.4.5)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->smote_variants) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->smote_variants) (57.2.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->smote_variants) (1.34.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->smote_variants) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->smote_variants) (2.23.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard~=2.5->tensorflow->smote_variants) (0.6.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->smote_variants) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->smote_variants) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->smote_variants) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->smote_variants) (1.3.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow->smote_variants) (4.6.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow->smote_variants) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->smote_variants) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->smote_variants) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->smote_variants) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow->smote_variants) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow->smote_variants) (3.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->markdown>=2.6.8->tensorboard~=2.5->tensorflow->smote_variants) (3.5.0)
# Building wheels for collected packages: minisom, statistics
#   Building wheel for minisom (setup.py) ... done
#   Created wheel for minisom: filename=MiniSom-2.2.9-py3-none-any.whl size=8594 sha256=1964be60164ae88346f8dc3ba9207628e01e38dedac65bea0ad88a9bedd18927
#   Stored in directory: /root/.cache/pip/wheels/3d/a1/10/f50b6f4865652eac239a2700de411c3078c27e1318320e494c
#   Building wheel for statistics (setup.py) ... done
#   Created wheel for statistics: filename=statistics-1.0.3.5-py3-none-any.whl size=7452 sha256=4970c1069028b464920a76942c683f448598c04c4091741d835300858b7580aa
#   Stored in directory: /root/.cache/pip/wheels/37/09/e1/49ee45c0ce248a6e9c986aae82d32bbcba09c9f3b9d0c3406a
# Successfully built minisom statistics
# Installing collected packages: statistics, minisom, smote-variants
# Successfully installed minisom-2.2.9 smote-variants-0.4.0 statistics-1.0.3.5

# %%
import importlib
import header

importlib.reload(header) # For reloading after making changes
from header import *

# %% [markdown]
# <a id="CGAN"><h1>Select GAN and Dataset and Flags</h1></a>

# %%
# GAN_type = 'GAN'
# GAN_type = 'CGAN'
# GAN_type = 'WGAN'
# GAN_type = 'WCGAN'
# GAN_type = 'EVAGAN'
# GAN_type = 'ACGAN_CV'
GAN_type = 'ACGAN_CC'
# GAN_type = 'EVAGAN_CV'


# DATA_SET = 'ISCX-2014'
# DATA_SET = 'CIC-2017'
DATA_SET = 'CIC-2018'
# DATA_SET = 'UNSW_BotIoT'


# DATA_SET = 'Drebin'

# DATA_SET = 'Darknet'

# %% [markdown]
# <a id="GPU Settings"><h2>Set Flags</h2></a>

# %%
begin_from_start = 1
take_chunk = 0
required_epochs = 150

DISPLAY_FEATURES = 0
EVALUATION_PARAMETER = 'Accuracy'
SAVE_ONLY_BOT_DATA = 0
USE_KMEANS_FOR_CLASSIFICATION = 1

BALANCE_THE_DATASET = 1

labels =[]

USE_ONLY_TRAIN_SET = 1

USE_ALL_CLASSIFIERS = 0

ACCU_EVAL_TEST = 0
RCL_EVAL_TEST = 0

VISUAL_TEST_OVERLAPPING = 1

CSV_ONE_BOT = 0

VIEW_ALL_BOTS = 0

CTU_NERIS = 0

SINGLE_WEIGHT_CLASSIFIER_TEST_C2ST = 0
SINGLE_WEIGHT_CLASSIFIER_TEST_PROPOSED_METHODOLOGY = 0

C2ST_BLACK_BOX_TEST = 0
BOTSHOT_BLACK_BOX_TEST = 0

C2ST_BLACK_BOX_TEST_AFTER_GAN_TRAINING = 0
BOTSHOT_BLACK_BOX_TEST_AFTER_GAN_TRAINING = 0

GENERATE_OTHERS_DATA = 1

# %% [markdown]
# <a id="CGAN"><h1>Set Paths</h1></a>

# %%
MAIN_CODE_PATH = os.getcwd()
print (MAIN_CODE_PATH)
# Out:
# /content/drive/My Drive/PhD/Development/code/Current/EVAGAN

# %%
DATA_SET_PATH = MAIN_CODE_PATH + '/Dataset/' +  DATA_SET + '/'
CACHE_PATH = MAIN_CODE_PATH + '/cache/' + GAN_type + '/'
FIGS_PATH = MAIN_CODE_PATH  + '/figs/' + GAN_type + '/'

# %%
print(DATA_SET_PATH)
print(CACHE_PATH)
print(FIGS_PATH)
# Out:
# /content/drive/My Drive/PhD/Development/code/Current/EVAGAN/Dataset/CIC-2018/
# /content/drive/My Drive/PhD/Development/code/Current/EVAGAN/cache/ACGAN_CC/
# /content/drive/My Drive/PhD/Development/code/Current/EVAGAN/figs/ACGAN_CC/

# %% [markdown]
# <a id="GPU Settings"><h2>Check Available GPUs</h2></a>

# %%
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %% [markdown]
# <a id="GPU Settings"><h2>Import Dataset</h2></a>

# %%
# %cd $DATA_SET_PATH
# !ls
# Out:
# /content/drive/My Drive/PhD/Development/code/Current/EVAGAN/Dataset/CIC-2018
#  best_losses.csv
#  CGAN_data_frame_of_bots_0.csv
#  CGAN_data_frame_of_bots_10.csv
#  CGAN_data_frame_of_bots_2.csv
#  CGAN_data_frame_of_bots_4.csv
#  CGAN_data_frame_of_bots_6.csv
#  CGAN_data_frame_of_bots_8.csv
#  CGAN_losses.csv
#  Friday-02-03-2018_TrafficForML_CICFlowMeter.csv
# 'Friday-02-03-2018_TrafficForML_CICFlowMeter.csv_(Preprocessed).csv'
#  GAN_0contour.eps
#  GAN_10contour.eps
#  GAN_2contour.eps
#  GAN_4contour.eps
#  GAN_6contour.eps
#  GAN_8contour.eps
#  GAN_data_frame_of_bots_0.csv
#  GAN_data_frame_of_bots_10.csv
#  GAN_data_frame_of_bots_2.csv
#  GAN_data_frame_of_bots_4.csv
#  GAN_data_frame_of_bots_6.csv
#  GAN_data_frame_of_bots_8.csv
#  GAN_losses.csv
#  GANlosses.csv
#  shuffled_T_B.csv

# %%
if begin_from_start:        

    if DATA_SET == 'ISCX-2014':
        training_data = prepare_ISCX_2014_data(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'ISCX_Botnet-Training.pcap_Flow.csv')
        testing_data = prepare_ISCX_2014_data(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'ISCX_Botnet-Testing.pcap_Flow.csv') 
    
    elif DATA_SET == 'CIC-2017':
        training_data = prepare_cic_2017_data(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'CIC_Friday_bot.csv')
        testing_data = prepare_cic_2017_data(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'CIC_Friday_bot.csv')
        
    elif DATA_SET == 'CIC-2018':
        training_data = prepare_cic_2018_data(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'Friday-02-03-2018_TrafficForML_CICFlowMeter.csv')
        testing_data = prepare_cic_2018_data(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'Friday-02-03-2018_TrafficForML_CICFlowMeter.csv')
        
    elif DATA_SET == 'UNSW_BotIoT':
        training_data = prepare_UNSW_IoT(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'UNSW_2018_IoT_Botnet_Final_10_best_Training.csv')
        testing_data = prepare_UNSW_IoT(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'UNSW_2018_IoT_Botnet_Final_10_best_Testing.csv')
        
    elif DATA_SET == 'Darknet':
        training_data = prepare_DARKNET_2020_data(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'Darknet.csv')
        testing_data = prepare_DARKNET_2020_data(PATH = DATA_SET_PATH, INPUT_FILE_NAME = r'Darknet.csv')
        
        

    print('Dataset preprocessed: ' + DATA_SET)
    
else:

    if DATA_SET == 'ISCX-2014':
        INPUT_TRAINING_FILE_NAME = r'ISCX_Botnet-Training.pcap_Flow.csv_VIRUT'
        INPUT_TESTING_FILE_NAME = r'ISCX_Botnet-Testing.pcap_Flow.csv_VIRUT'
        
    elif DATA_SET == 'CIC-2017':
        INPUT_TRAINING_FILE_NAME = r'CIC_Friday_bot.csv'
        INPUT_TESTING_FILE_NAME = r'CIC_Friday_bot.csv'
        
    elif DATA_SET == 'CIC-2018':
        INPUT_TRAINING_FILE_NAME = r'Friday-02-03-2018_TrafficForML_CICFlowMeter.csv'
        INPUT_TESTING_FILE_NAME = r'Friday-02-03-2018_TrafficForML_CICFlowMeter.csv'
        
    elif DATA_SET == 'BoT-IoT':
        INPUT_TRAINING_FILE_NAME = r'UNSW_2018_IoT_Botnet_Final_10_best_Training.csv'
        INPUT_TESTING_FILE_NAME = r'UNSW_2018_IoT_Botnet_Final_10_best_Testing.csv'
        
    elif DATA_SET == 'Drebin':
        INPUT_TRAINING_FILE_NAME = r'Drebin_API_Dataset.csv'
        INPUT_TESTING_FILE_NAME = r'Drebin_API_Dataset.csv'
        
    elif DATA_SET == 'Darknet':
        INPUT_TRAINING_FILE_NAME = r'Darknet.csv'
        INPUT_TESTING_FILE_NAME = r'Darknet.csv'

    training_data = pd.read_csv (INPUT_TRAINING_FILE_NAME + '_(Preprocessed).csv', low_memory=False)
    training_data= training_data.drop(['Unnamed: 0'], axis=1)
    
    testing_data = pd.read_csv (INPUT_TESTING_FILE_NAME + '_(Preprocessed).csv', low_memory=False)
    testing_data= testing_data.drop(['Unnamed: 0'], axis=1) 
    
    print('Dataset Imported: ' + DATA_SET)
    print('Training set: '+ str(training_data.shape))
    print('Testng set: '+ str(training_data.shape))
# Out:
# Processing File: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv DATA shape: (1048575, 80)
# The shape of dataset is:  (1048575, 80)
# Before Preprocesing: Total: (1048575, 80)
# Before Preprocesing: Normal: (762384, 80)
# Before Preprocesing: Bots: (286191, 80)
# Data Shape before droping NULL and INF values:
# (1048575, 80)
# Data Shape after droping NULL and INF values:
# (1044525, 80)
# data_df after removing categorical features
# (1044525, 77)
# data_df after removing Label column
# (1044525, 76)
#  Data Columns after converting to Float
#        Flow Duration  Tot Fwd Pkts  ...      Idle Max      Idle Min
# count   1.044525e+06  1.044525e+06  ...  1.044525e+06  1.044525e+06
# mean    1.155885e+07  5.902530e+00  ...  4.882636e+06  4.695151e+06
# std     3.017092e+07  8.920527e+01  ...  1.759949e+07  1.736415e+07
# min     1.000000e+00  1.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%     5.190000e+02  2.000000e+00  ...  0.000000e+00  0.000000e+00
# 50%     1.127400e+04  3.000000e+00  ...  0.000000e+00  0.000000e+00
# 75%     2.221014e+06  7.000000e+00  ...  0.000000e+00  0.000000e+00
# max     1.200000e+08  4.315900e+04  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 76 columns]
# INF values before removing: Int64Index([], dtype='int64')
# INF values removed and Data reindexed
# Data before removing std = 0 columns
# (1044525, 76)
# (1044525, 77)
# Data after removing std = 0 columns
# (1044525, 67)
#        Flow Duration  Tot Fwd Pkts  ...      Idle Max      Idle Min
# count   1.044525e+06  1.044525e+06  ...  1.044525e+06  1.044525e+06
# mean    1.155885e+07  5.902530e+00  ...  4.882636e+06  4.695151e+06
# std     3.017092e+07  8.920527e+01  ...  1.759949e+07  1.736415e+07
# min     1.000000e+00  1.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%     5.190000e+02  2.000000e+00  ...  0.000000e+00  0.000000e+00
# 50%     1.127400e+04  3.000000e+00  ...  0.000000e+00  0.000000e+00
# 75%     2.221014e+06  7.000000e+00  ...  0.000000e+00  0.000000e+00
# max     1.200000e+08  4.315900e+04  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 66 columns]
# HEREEEEEEEEEEEEEEEEEEEEEEEEEEE+++++++++++++++++++++++++++++++>>>>>>>>>>>>>>>>>>>>>>
#        Flow Duration  Tot Fwd Pkts  ...      Idle Max      Idle Min
# count   1.044525e+06  1.044525e+06  ...  1.044525e+06  1.044525e+06
# mean    9.632377e-02  1.135949e-04  ...  4.068863e-02  3.912626e-02
# std     2.514243e-01  2.066946e-03  ...  1.466624e-01  1.447013e-01
# min     0.000000e+00  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%     4.316667e-06  2.317068e-05  ...  0.000000e+00  0.000000e+00
# 50%     9.394167e-05  4.634135e-05  ...  0.000000e+00  0.000000e+00
# 75%     1.850844e-02  1.390241e-04  ...  0.000000e+00  0.000000e+00
# max     1.000000e+00  1.000000e+00  ...  1.000000e+00  1.000000e+00
#
# [8 rows x 66 columns]
# INF values: 726633
# Any Left over INF values: Int64Index([], dtype='int64')
#  Data Columns after removing Flow ID: Index(['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts',
#        'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min',
#        'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max',
#        'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s',
#        'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s',
#        'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std',
#        'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt',
#        'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'ECE Flag Cnt',
#        'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg',
#        'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts',
#        'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts',
#        'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std',
#        'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max',
#        'Idle Min', 'Label'],
#       dtype='object')
# Data Shape before droping NULL and INF values:
# (1044525, 67)
# Data Shape before droping NULL and INF values:
# (533975, 67)
# After Preprocesing: Bots: (143014, 67)
# After Preprocesing: Total: (393521, 67)
# After Preprocesing: Normal: (390961, 67)
# After Preprocesing: Bots Chunk: (2560, 67)
# File: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv_(Preprocessed).csv Saving ...
# File: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv_(Preprocessed).csv saved to directory
# Processing File: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv DATA shape: (1048575, 80)
# The shape of dataset is:  (1048575, 80)
# Before Preprocesing: Total: (1048575, 80)
# Before Preprocesing: Normal: (762384, 80)
# Before Preprocesing: Bots: (286191, 80)
# Data Shape before droping NULL and INF values:
# (1048575, 80)
# Data Shape after droping NULL and INF values:
# (1044525, 80)
# data_df after removing categorical features
# (1044525, 77)
# data_df after removing Label column
# (1044525, 76)
#  Data Columns after converting to Float
#        Flow Duration  Tot Fwd Pkts  ...      Idle Max      Idle Min
# count   1.044525e+06  1.044525e+06  ...  1.044525e+06  1.044525e+06
# mean    1.155885e+07  5.902530e+00  ...  4.882636e+06  4.695151e+06
# std     3.017092e+07  8.920527e+01  ...  1.759949e+07  1.736415e+07
# min     1.000000e+00  1.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%     5.190000e+02  2.000000e+00  ...  0.000000e+00  0.000000e+00
# 50%     1.127400e+04  3.000000e+00  ...  0.000000e+00  0.000000e+00
# 75%     2.221014e+06  7.000000e+00  ...  0.000000e+00  0.000000e+00
# max     1.200000e+08  4.315900e+04  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 76 columns]
# INF values before removing: Int64Index([], dtype='int64')
# INF values removed and Data reindexed
# Data before removing std = 0 columns
# (1044525, 76)
# (1044525, 77)
# Data after removing std = 0 columns
# (1044525, 67)
#        Flow Duration  Tot Fwd Pkts  ...      Idle Max      Idle Min
# count   1.044525e+06  1.044525e+06  ...  1.044525e+06  1.044525e+06
# mean    1.155885e+07  5.902530e+00  ...  4.882636e+06  4.695151e+06
# std     3.017092e+07  8.920527e+01  ...  1.759949e+07  1.736415e+07
# min     1.000000e+00  1.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%     5.190000e+02  2.000000e+00  ...  0.000000e+00  0.000000e+00
# 50%     1.127400e+04  3.000000e+00  ...  0.000000e+00  0.000000e+00
# 75%     2.221014e+06  7.000000e+00  ...  0.000000e+00  0.000000e+00
# max     1.200000e+08  4.315900e+04  ...  1.200000e+08  1.200000e+08
#
# [8 rows x 66 columns]
# HEREEEEEEEEEEEEEEEEEEEEEEEEEEE+++++++++++++++++++++++++++++++>>>>>>>>>>>>>>>>>>>>>>
#        Flow Duration  Tot Fwd Pkts  ...      Idle Max      Idle Min
# count   1.044525e+06  1.044525e+06  ...  1.044525e+06  1.044525e+06
# mean    9.632377e-02  1.135949e-04  ...  4.068863e-02  3.912626e-02
# std     2.514243e-01  2.066946e-03  ...  1.466624e-01  1.447013e-01
# min     0.000000e+00  0.000000e+00  ...  0.000000e+00  0.000000e+00
# 25%     4.316667e-06  2.317068e-05  ...  0.000000e+00  0.000000e+00
# 50%     9.394167e-05  4.634135e-05  ...  0.000000e+00  0.000000e+00
# 75%     1.850844e-02  1.390241e-04  ...  0.000000e+00  0.000000e+00
# max     1.000000e+00  1.000000e+00  ...  1.000000e+00  1.000000e+00
#
# [8 rows x 66 columns]
# INF values: 726633
# Any Left over INF values: Int64Index([], dtype='int64')
#  Data Columns after removing Flow ID: Index(['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts',
#        'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min',
#        'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max',
#        'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s',
#        'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max',
#        'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std',
#        'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean',
#        'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags',
#        'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s',
#        'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std',
#        'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt',
#        'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'ECE Flag Cnt',
#        'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg',
#        'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts',
#        'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts',
#        'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std',
#        'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max',
#        'Idle Min', 'Label'],
#       dtype='object')
# Data Shape before droping NULL and INF values:
# (1044525, 67)
# Data Shape before droping NULL and INF values:
# (533975, 67)
# After Preprocesing: Bots: (143014, 67)
# After Preprocesing: Total: (393521, 67)
# After Preprocesing: Normal: (390961, 67)
# After Preprocesing: Bots Chunk: (2560, 67)
# File: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv_(Preprocessed).csv Saving ...
# File: Friday-02-03-2018_TrafficForML_CICFlowMeter.csv_(Preprocessed).csv saved to directory
# Dataset preprocessed: CIC-2018

# %%
training_data = training_data.replace([np.inf, -np.inf], np.nan).dropna(how="any").reset_index(drop=True)
print(training_data.describe())
# Out:
#        Flow Duration   Tot Fwd Pkts  ...       Idle Min          Label
# count  393521.000000  393521.000000  ...  393521.000000  393521.000000
# mean        0.145840       0.000249  ...       0.033240       0.993495
# std         0.304724       0.003328  ...       0.106079       0.080393
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.002439       0.000070  ...       0.000000       1.000000
# 50%         0.018163       0.000162  ...       0.000000       1.000000
# 75%         0.043428       0.000232  ...       0.000000       1.000000
# max         1.000000       1.000000  ...       1.000000       1.000000
#
# [8 rows x 67 columns]

# %% [markdown]
# <a id="GPU Settings"><h2>Display Features</h2></a>

# %%
if DISPLAY_FEATURES: 
    unified_df = training_data.copy()
    X_cols = unified_df.columns[:-1]
    y_cols = unified_df.columns[-1]



    axarr = [[]]*len(X_cols)
    columns = 4
    rows = int( np.ceil( len(X_cols) / columns ) )
    f, fig = plt.subplots( figsize=(columns*2.5, rows*2) )

    f.suptitle('Data Distributions by Feature and Label', size=16)

    for i, col in enumerate(X_cols[:]):
        axarr[i] = plt.subplot2grid( (int(rows), int(columns)), (int(i//columns), int(i%columns)) )


        axarr[i].hist( unified_df.loc[ unified_df.Label == 0, col ] , label=['Normal'], color=('#009933'), alpha=0.5,
                              bins=np.linspace( np.percentile(unified_df[col],0), np.percentile(unified_df[col],100),50 ),
                              density=True )

        axarr[i].hist( unified_df.loc[ unified_df.Label == 1, col ] , label=['Real Bot'], color=['#FF0000'], alpha=0.5,
                              bins=np.linspace( np.percentile(unified_df[col],0), np.percentile(unified_df[col],100),50 ),
                              density=True )

        axarr[i].set_xlabel(col, size=12)
    #     axarr[i].set_ylim([0,1])
        axarr[i].tick_params(axis='both', labelsize=10)
        if i == 0: 
            legend = axarr[i].legend()
            legend.get_frame().set_facecolor('white')
        if i%4 != 0 : 
            axarr[i].tick_params(axis='y', left=True, labelleft=True)
        else:
            axarr[i].set_ylabel('Fraction',size=12)

    plt.tight_layout(rect=[0,0,1,0.95]) # xmin, ymin, xmax, ymax
    # plt.savefig('plots/Engineered_Data_Distributions.png')

    plt.show()
    
# else: 
#     print('Pair Plotting..')
# #     sns.pairplot(training_data, hue="Label")
    
#     sns.pairplot(training_data, vars=['Flow Duration', 'Total Fwd Packet', 'Total Bwd packets',
#        'Total Length of Fwd Packet', 'Total Length of Bwd Packet'], hue="Label")
    
#     sns.pairplot(penguins, hue="species", markers=["o", "s", "D"])

# %% [markdown]
# <a id="GPU Settings"><h2>Select Botnet</h2></a>

# %%
bots = training_data.loc[ training_data['Label']==0 ].copy()
normal = training_data.loc[ training_data['Label']==1 ].copy()

print('Normal before chunk: ' + str(normal.shape))    
print('Real Bots before chunk: ' + str(bots.shape)) 

if take_chunk:
    bots = bots[0:512]
    
print('Normal: ' + str(normal.shape))    
print('Real Bots: ' + str(bots.shape))
# Out:
# Normal before chunk: (390961, 67)
# Real Bots before chunk: (2560, 67)
# Normal: (390961, 67)
# Real Bots: (2560, 67)

# %%
Train = training_data.copy()

# %%
bots_count =  pd.DataFrame( [ [np.sum(bots['Label']==i)] for i in np.unique(bots['Label']) ], columns=['count'], index=np.unique(bots['Label']) )

label_cols = [ i for i in bots.columns if 'Label' in i ]
data_cols = [ i for i in bots.columns if i not in label_cols ]

train_no_label = bots[ data_cols ].reset_index(drop=True)

print(bots_count['count'])
# Out:
# 0    2560
# Name: count, dtype: int64

# %%
train_data = bots

# %% [markdown]
# <a id="Classification"><h1>Classification</h1></a>

# %%
# %%time 
# if GAN_type == 'CGAN' or GAN_type == 'WCGAN':
if USE_KMEANS_FOR_CLASSIFICATION:
    algorithms = [ 
    #     [ 'KMeans', cluster.KMeans, (), {'random_state':0} ],
        [ 'KMeans', cluster.KMeans, (), {'n_clusters':1, 'random_state':0} ],
    #     [ 'KMeans 3', cluster.KMeans, (), {'n_clusters':3, 'random_state':0} ],
    #     [ 'Agglomerative', cluster.AgglomerativeClustering, (), {} ],
    #     [ 'Agglomerative', cluster.AgglomerativeClustering, (), {'linkage': 'ward', 'n_clusters': 3} ],
    #     [ 'Agg. Ave 3', cluster.AgglomerativeClustering, (), {'linkage': 'average', 'n_clusters': 3} ],
    #     [ 'Agg. Complete 3', cluster.AgglomerativeClustering, (), {'linkage': 'complete', 'n_clusters': 3} ],
    #     [ 'DBSCAN', cluster.DBSCAN, (), {'eps':0.025} ],
    #     [ 'HDBSCAN', hdbscan.HDBSCAN, (), {} ],
    #     [ 'HDBSCAN', hdbscan.HDBSCAN, (), {'min_cluster_size':10, 'min_samples':1, } ],
    #     [ 'HDBSCAN 2 10', hdbscan.HDBSCAN, (), {'min_cluster_size':2, 'min_samples':10, } ],
    #     [ 'HDBSCAN 10 10 ', hdbscan.HDBSCAN, (), {'min_cluster_size':10, 'min_samples':10, } ],
    ]

    rows = len(algorithms)
    columns = 1
    fig, ax = plt.subplots(3, 2, figsize=(3, 2),
                            constrained_layout=True)

    for i, [name, algorithm, args, kwds] in enumerate(algorithms):

        labels = algorithm(*args, **kwds).fit_predict(train_no_label)
        print(len(labels))
        colors = np.clip(labels,-1,9)
        colors = [ 'C'+str(i) if i>-1 else 'white' for i in colors ]

        plt.subplot(rows,columns,i*columns+1)
        plt.scatter(train_no_label[data_cols[0]], train_no_label[data_cols[1]], c=colors)
        plt.xlabel(data_cols[0]), plt.ylabel(data_cols[1])
        plt.title(name)
            

#     else:
#         labels = train_bots_only['Label'].values.tolist() 
#         sns.set(style="ticks", color_codes=True) # Remove background and grid

#     #     g = sns.scatterplot(data_cols[0],data_cols[1], data=train, hue=labels)

#     #     plt.show() 


#         plt.figure()
#         ax = sns.countplot(y="Label", data=train_bots_only) # for Seaborn version 0.7 and more
#         for p in ax.patches:
#             ax.text(p.get_y() + p.get_width() + 2700 , p.get_y()+p.get_height()-0.1, p.get_width(), ha="center") 

#         ax.set_ylabel('Botnets')

#         plt.savefig('Botnet-Trainset.pdf', dpi=600)
#         plt.show()




#         plt.figure(figsize=(6, 6))
#         ax = sns.countplot(y="Label", data=test_bots_only) # for Seaborn version 0.7 and more
#         for p in ax.patches:
#             ax.text(p.get_y() + p.get_width() + 6000 , p.get_y()+p.get_height()-0.1, p.get_width(), ha="center") 

#         ax.set_ylabel('Botnets')

#         plt.savefig('Botnet-Testset.pdf', dpi=600)
#         plt.show()

#     #     g = sns.catplot(x="class", hue="who", col="survived", data=titanic, kind="count", height=4, aspect=.7);


#     #     sns.pairplot(data=train, vars=[data_cols[0], data_cols[1]], hue='Label')


#     # plt.grid(False)
#     # plt.show()
#     print(train_no_label.describe())
    
    botnet_w_classes = train_no_label.copy()
    botnet_w_classes['Label'] = labels

#     print(botnet_w_classes.describe())
    train_data = botnet_w_classes
    
# else:
#     train_data = train_no_label
# Out:
# 2560
# CPU times: user 251 ms, sys: 150 ms, total: 402 ms
# Wall time: 395 ms

# %%
train_data['Label']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 2555    0
# 2556    0
# 2557    0
# 2558    0
# 2559    0
# Name: Label, Length: 2560, dtype: int32

# %% [markdown]
# <a id="GPU Settings"><h2>GAN Training</h2></a>

# %%
# import header
# import importlib
# importlib.reload(header) # For reloading after making changes
# from header import *


gpu_device = '/device:GPU:1'
physical_devices = tf.config.list_physical_devices('GPU') 
for gpu_instance in physical_devices: 
    tf.config.experimental.set_memory_growth(gpu_instance, True)

#----------------------------------
# Set neurons and batch size
#----------------------------------
if GAN_type == 'GAN':
    base_n_count = 256
    batch_size =  128
elif GAN_type == 'CGAN':
    base_n_count = 256
    batch_size =  128
elif GAN_type == 'WGAN':
    base_n_count = 128
    batch_size =  256
elif GAN_type == 'WCGAN':
    base_n_count = 128
    batch_size =  128
    
elif GAN_type == 'EVAGAN':
    base_n_count = 256
    batch_size =  256
    
elif GAN_type == 'ACGAN_CC':
    base_n_count = 256
    batch_size =  256
    
elif GAN_type == 'ACGAN_CV':
    base_n_count = 32
    batch_size =  32
    
elif GAN_type == 'EVAGAN_CV':
    base_n_count = 256
    batch_size =  256
#----------------------------------


result = train_data

remaining = train_data.shape[0] % batch_size

if remaining > 0:
    if remaining < train_data.shape[0]:
        additional = batch_size - remaining
        _additional = train_data.loc[train_data.shape[0]-additional:train_data.shape[0],: ]  
        
        frames = [train_data, _additional]
        result = pd.concat(frames).reset_index(drop=True)

print('Result: ' + str(result.shape))
# ---------------------------------
nb_steps = required_epochs * result.shape[0] // batch_size

log_interval = result.shape[0] // batch_size # We are setting this as an epoch. This depends on data size.

print("log_interval : " + str(log_interval))

# nb_steps = TRAINING_ITERATIONS  # 50000 # Add one for logging of the last interval
print("Total Batch Iterations: " + str(nb_steps))
rand_noise_dim = 100 


k_d = 1  # number of critic network updates per adversarial training step
k_g = 1  # number of generator network updates per adversarial training step

critic_pre_train_steps = 100# 100  # number of steps to pre-train the critic before starting adversarial training

generator_model_path, discriminator_model_path, loss_pickle_path = None, None, None

show = True 
train = result#.copy().reset_index(drop=True) # botnet only with labels from classification



label_cols = [ i for i in train.columns if 'Label' in i ]

data_cols = [ i for i in train.columns if i not in label_cols ]

print(data_cols)

train_no_label = train[ data_cols ]

train_no_label = round(train_no_label, 4)

# if SAVE_ONLY_BOT_DATA:
#     train_no_label.to_csv(str(DATA_SET_PATH) + 'ONLY_BOTNET_DATA_(Preprocessed).csv')
#     print('File: ' + 'ONLY_BOTNET_DATA_(Preprocessed).csv saved to directory')   



test_size = train.shape[0] 
learning_rate = 5e-4


TODAY = DATA_SET + '_' + str(datetime.datetime.now()) 

print(TODAY)

Test = testing_data.copy()

arguments = [rand_noise_dim, nb_steps, batch_size, 
             k_d, k_g, critic_pre_train_steps, log_interval, learning_rate, base_n_count,
            CACHE_PATH, FIGS_PATH, show, test_size, gpu_device, EVALUATION_PARAMETER, TODAY ]

if GAN_type == 'GAN':
    best_losses = adversarial_training_GAN(arguments, train_no_label, data_cols) # GAN    
elif GAN_type == 'CGAN':    
    best_losses = adversarial_training_CGAN(arguments, train, data_cols=data_cols, label_cols=label_cols ) # CGAN      
elif GAN_type == 'WGAN':
    best_losses = adversarial_training_WGAN(arguments, train_no_label, data_cols) # WGAN    
elif GAN_type == 'WCGAN':    
    best_losses = adversarial_training_WCGAN(arguments, train, data_cols=data_cols, label_cols=label_cols ) # WCGAN      
    
    
# if GAN_type == 'WGAN':
#     best_losses = train_WGAN(arguments, train_no_label, data_cols)
    
# elif GAN_type == 'GAN':
#     best_losses = train_GAN(arguments, train_no_label, data_cols)


elif GAN_type == 'EVAGAN':   

    best_losses = train_EVAGAN(arguments, train, Train, Test, data_cols)

elif GAN_type == 'EVAGAN_CV':   

    best_losses = train_EVAGAN_CV(arguments, train, Train, Test, data_cols)
    
    
    
elif GAN_type == 'ACGAN_CC':   

    best_losses = train_ACGAN_CC(arguments, train, Train, Test, data_cols)
    
elif GAN_type == 'ACGAN_CV':   

    best_losses = train_ACGAN_CV(arguments, train, Train, Test, data_cols)
# Out:
# Result: (2560, 67)
# log_interval : 10
# Total Batch Iterations: 1500
# ['Flow Duration', 'Tot Fwd Pkts', 'Tot Bwd Pkts', 'TotLen Fwd Pkts', 'TotLen Bwd Pkts', 'Fwd Pkt Len Max', 'Fwd Pkt Len Min', 'Fwd Pkt Len Mean', 'Fwd Pkt Len Std', 'Bwd Pkt Len Max', 'Bwd Pkt Len Min', 'Bwd Pkt Len Mean', 'Bwd Pkt Len Std', 'Flow Byts/s', 'Flow Pkts/s', 'Flow IAT Mean', 'Flow IAT Std', 'Flow IAT Max', 'Flow IAT Min', 'Fwd IAT Tot', 'Fwd IAT Mean', 'Fwd IAT Std', 'Fwd IAT Max', 'Fwd IAT Min', 'Bwd IAT Tot', 'Bwd IAT Mean', 'Bwd IAT Std', 'Bwd IAT Max', 'Bwd IAT Min', 'Fwd PSH Flags', 'Fwd Header Len', 'Bwd Header Len', 'Fwd Pkts/s', 'Bwd Pkts/s', 'Pkt Len Min', 'Pkt Len Max', 'Pkt Len Mean', 'Pkt Len Std', 'Pkt Len Var', 'FIN Flag Cnt', 'SYN Flag Cnt', 'RST Flag Cnt', 'PSH Flag Cnt', 'ACK Flag Cnt', 'URG Flag Cnt', 'ECE Flag Cnt', 'Down/Up Ratio', 'Pkt Size Avg', 'Fwd Seg Size Avg', 'Bwd Seg Size Avg', 'Subflow Fwd Pkts', 'Subflow Fwd Byts', 'Subflow Bwd Pkts', 'Subflow Bwd Byts', 'Init Fwd Win Byts', 'Init Bwd Win Byts', 'Fwd Act Data Pkts', 'Fwd Seg Size Min', 'Active Mean', 'Active Std', 'Active Max', 'Active Min', 'Idle Mean', 'Idle Std', 'Idle Max', 'Idle Min']
# CIC-2018_2021-08-14 14:53:30.663033
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                3232
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                2112
# _________________________________________________________________
# activation (Activation)      (None, 64)                0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# activation_1 (Activation)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 66)                8514
# _________________________________________________________________
# activation_2 (Activation)    (None, 66)                0
# =================================================================
# Total params: 23,074
# Trainable params: 22,626
# Non-trainable params: 448
# _________________________________________________________________
# []
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 128)               8576
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 128)               512
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 64)                256
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                2080
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 32)                0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# =================================================================
# Total params: 19,808
# Trainable params: 19,360
# Non-trainable params: 448
# _________________________________________________________________
# Directory 'CIC-2018_2021-08-14 14:53:30.663033' created
# Directory 'CIC-2018_2021-08-14 14:53:30.663033' created
# ACGAN 256 256
# ======================================================
# Batch Size Selected -------->>>>>>> 256
# ======================================================
# (390961, 67)
# (2560, 67)
# T_n: (273672, 67)
# (1792, 67) (273672, 67)
# Starting GAN Training..
# log_iteration: 1/150
# Average time per log_iteration: 52.93075752258301
# Time left = 2.19 hours
# Total Time Taken: 0.9 minutes
# Epoch#: 0 completed
# log_iteration: 2/150
# Average time per log_iteration: 38.99265122413635
# Time left = 1.6 hours
# Total Time Taken: 1.3 minutes
# Epoch#: 1 completed
# log_iteration: 3/150
# Average time per log_iteration: 34.368752002716064
# Time left = 1.4 hours
# Total Time Taken: 1.7 minutes
# Epoch#: 2 completed
# log_iteration: 4/150
# Average time per log_iteration: 32.48271018266678
# Time left = 1.32 hours
# Total Time Taken: 2.2 minutes
# Epoch#: 3 completed
# log_iteration: 5/150
# Average time per log_iteration: 30.306303024291992
# Time left = 1.22 hours
# Total Time Taken: 2.5 minutes
# Epoch#: 4 completed
# log_iteration: 6/150
# Average time per log_iteration: 28.865065733591717
# Time left = 1.15 hours
# Total Time Taken: 2.9 minutes
# Epoch#: 5 completed
# log_iteration: 7/150
# Average time per log_iteration: 28.98460054397583
# Time left = 1.15 hours
# Total Time Taken: 3.4 minutes
# Epoch#: 6 completed
# log_iteration: 8/150
# Average time per log_iteration: 28.674250930547714
# Time left = 1.13 hours
# Total Time Taken: 3.8 minutes
# Epoch#: 7 completed
# log_iteration: 9/150
# Average time per log_iteration: 28.334437873628403
# Time left = 1.11 hours
# Total Time Taken: 4.3 minutes
# Epoch#: 8 completed
# log_iteration: 10/150
# Average time per log_iteration: 27.699293327331542
# Time left = 1.08 hours
# Total Time Taken: 4.6 minutes
# Epoch#: 9 completed
# log_iteration: 11/150
# Average time per log_iteration: 27.9199050990018
# Time left = 1.08 hours
# Total Time Taken: 5.1 minutes
# Epoch#: 10 completed
# log_iteration: 12/150
# Average time per log_iteration: 27.389766116937
# Time left = 1.05 hours
# Total Time Taken: 5.5 minutes
# Epoch#: 11 completed
# log_iteration: 13/150
# Average time per log_iteration: 27.216892040692844
# Time left = 1.04 hours
# Total Time Taken: 5.9 minutes
# Epoch#: 12 completed
# log_iteration: 14/150
# Average time per log_iteration: 27.18610852105277
# Time left = 1.03 hours
# Total Time Taken: 6.3 minutes
# Epoch#: 13 completed
# log_iteration: 15/150
# Average time per log_iteration: 27.372451241811117
# Time left = 1.03 hours
# Total Time Taken: 6.8 minutes
# Epoch#: 14 completed
# log_iteration: 16/150
# Average time per log_iteration: 27.028892651200294
# Time left = 1.01 hours
# Total Time Taken: 7.2 minutes
# Epoch#: 15 completed
# log_iteration: 17/150
# Average time per log_iteration: 26.922293438630945
# Time left = 59.4 minutes
# Total Time Taken: 7.6 minutes
# Epoch#: 16 completed
# log_iteration: 18/150
# Average time per log_iteration: 26.823498341772293
# Time left = 58.8 minutes
# Total Time Taken: 8.0 minutes
# Epoch#: 17 completed
# log_iteration: 19/150
# Average time per log_iteration: 26.58249739596718
# Time left = 58.2 minutes
# Total Time Taken: 8.4 minutes
# Epoch#: 18 completed
# log_iteration: 20/150
# Average time per log_iteration: 26.76260361671448
# Time left = 58.2 minutes
# Total Time Taken: 8.9 minutes
# Epoch#: 19 completed
# log_iteration: 21/150
# Average time per log_iteration: 26.756568783805484
# Time left = 57.6 minutes
# Total Time Taken: 9.4 minutes
# Epoch#: 20 completed
# log_iteration: 22/150
# Average time per log_iteration: 26.89504657008431
# Time left = 57.6 minutes
# Total Time Taken: 9.9 minutes
# Epoch#: 21 completed
# log_iteration: 23/150
# Average time per log_iteration: 26.861181425011676
# Time left = 57.0 minutes
# Total Time Taken: 10.3 minutes
# Epoch#: 22 completed
# log_iteration: 24/150
# Average time per log_iteration: 26.79479779799779
# Time left = 56.4 minutes
# Total Time Taken: 10.7 minutes
# Epoch#: 23 completed
# log_iteration: 25/150
# Average time per log_iteration: 26.79033285140991
# Time left = 55.8 minutes
# Total Time Taken: 11.2 minutes
# Epoch#: 24 completed
# log_iteration: 26/150
# Average time per log_iteration: 26.92344233622918
# Time left = 55.8 minutes
# Total Time Taken: 11.7 minutes
# Epoch#: 25 completed
# log_iteration: 27/150
# Average time per log_iteration: 26.753588173124527
# Time left = 54.6 minutes
# Total Time Taken: 12.0 minutes
# Epoch#: 26 completed
# log_iteration: 28/150
# Average time per log_iteration: 26.758824433599198
# Time left = 54.6 minutes
# Total Time Taken: 12.5 minutes
# Epoch#: 27 completed
# log_iteration: 29/150
# Average time per log_iteration: 26.7331063747406
# Time left = 54.0 minutes
# Total Time Taken: 12.9 minutes
# Epoch#: 28 completed
# log_iteration: 30/150
# Average time per log_iteration: 26.837356797854106
# Time left = 53.4 minutes
# Total Time Taken: 13.4 minutes
# Epoch#: 29 completed
# log_iteration: 31/150
# Average time per log_iteration: 26.674423333137266
# Time left = 52.8 minutes
# Total Time Taken: 13.8 minutes
# Epoch#: 30 completed
# log_iteration: 32/150
# Average time per log_iteration: 26.546673856675625
# Time left = 52.2 minutes
# Total Time Taken: 14.2 minutes
# Epoch#: 31 completed
# log_iteration: 33/150
# Average time per log_iteration: 26.538566358161695
# Time left = 51.6 minutes
# Total Time Taken: 14.6 minutes
# Epoch#: 32 completed
# log_iteration: 34/150
# Average time per log_iteration: 26.54440738874323
# Time left = 51.6 minutes
# Total Time Taken: 15.0 minutes
# Epoch#: 33 completed
# log_iteration: 35/150
# Average time per log_iteration: 26.51952554838998
# Time left = 51.0 minutes
# Total Time Taken: 15.5 minutes
# Epoch#: 34 completed
# log_iteration: 36/150
# Average time per log_iteration: 26.621271332105
# Time left = 50.4 minutes
# Total Time Taken: 16.0 minutes
# Epoch#: 35 completed
# log_iteration: 37/150
# Average time per log_iteration: 26.493306147085654
# Time left = 49.8 minutes
# Total Time Taken: 16.3 minutes
# Epoch#: 36 completed
# log_iteration: 38/150
# Average time per log_iteration: 26.580130081427725
# Time left = 49.8 minutes
# Total Time Taken: 16.8 minutes
# Epoch#: 37 completed
# log_iteration: 39/150
# Average time per log_iteration: 26.46284939081241
# Time left = 49.2 minutes
# Total Time Taken: 17.2 minutes
# Epoch#: 38 completed
# log_iteration: 40/150
# Average time per log_iteration: 26.55935583114624
# Time left = 48.6 minutes
# Total Time Taken: 17.7 minutes
# Epoch#: 39 completed
# log_iteration: 41/150
# Average time per log_iteration: 26.4510526424501
# Time left = 48.0 minutes
# Total Time Taken: 18.1 minutes
# Epoch#: 40 completed
# log_iteration: 42/150
# Average time per log_iteration: 26.441590661094303
# Time left = 47.4 minutes
# Total Time Taken: 18.5 minutes
# Epoch#: 41 completed
# log_iteration: 43/150
# Average time per log_iteration: 26.426149728686312
# Time left = 47.4 minutes
# Total Time Taken: 18.9 minutes
# Epoch#: 42 completed
# log_iteration: 44/150
# Average time per log_iteration: 26.51288551634008
# Time left = 46.8 minutes
# Total Time Taken: 19.4 minutes
# Epoch#: 43 completed
# log_iteration: 45/150
# Average time per log_iteration: 26.481551451153226
# Time left = 46.2 minutes
# Total Time Taken: 19.9 minutes
# Epoch#: 44 completed
# log_iteration: 46/150
# Average time per log_iteration: 26.4666414571845
# Time left = 45.6 minutes
# Total Time Taken: 20.3 minutes
# Epoch#: 45 completed
# log_iteration: 47/150
# Average time per log_iteration: 26.365238737552723
# Time left = 45.0 minutes
# Total Time Taken: 20.7 minutes
# Epoch#: 46 completed
# log_iteration: 48/150
# Average time per log_iteration: 26.3499397734801
# Time left = 45.0 minutes
# Total Time Taken: 21.1 minutes
# Epoch#: 47 completed
# log_iteration: 49/150
# Average time per log_iteration: 26.35012072446395
# Time left = 44.4 minutes
# Total Time Taken: 21.5 minutes
# Epoch#: 48 completed
# log_iteration: 50/150
# Average time per log_iteration: 26.350797638893127
# Time left = 43.8 minutes
# Total Time Taken: 22.0 minutes
# Epoch#: 49 completed
# log_iteration: 51/150
# Average time per log_iteration: 26.334447762545416
# Time left = 43.2 minutes
# Total Time Taken: 22.4 minutes
# Epoch#: 50 completed
# log_iteration: 52/150
# Average time per log_iteration: 26.251421589117783
# Time left = 42.6 minutes
# Total Time Taken: 22.8 minutes
# Epoch#: 51 completed
# log_iteration: 53/150
# Average time per log_iteration: 26.326168217748965
# Time left = 42.6 minutes
# Total Time Taken: 23.3 minutes
# Epoch#: 52 completed
# log_iteration: 54/150
# Average time per log_iteration: 26.234757622083027
# Time left = 42.0 minutes
# Total Time Taken: 23.6 minutes
# Epoch#: 53 completed
# log_iteration: 55/150
# Average time per log_iteration: 26.295216703414916
# Time left = 41.4 minutes
# Total Time Taken: 24.1 minutes
# Epoch#: 54 completed
# log_iteration: 56/150
# Average time per log_iteration: 26.356514487947738
# Time left = 41.4 minutes
# Total Time Taken: 24.6 minutes
# Epoch#: 55 completed
# log_iteration: 57/150
# Average time per log_iteration: 26.347421503903572
# Time left = 40.8 minutes
# Total Time Taken: 25.0 minutes
# Epoch#: 56 completed
# log_iteration: 58/150
# Average time per log_iteration: 26.34531707599245
# Time left = 40.2 minutes
# Total Time Taken: 25.5 minutes
# Epoch#: 57 completed
# log_iteration: 59/150
# Average time per log_iteration: 26.40091356180482
# Time left = 40.2 minutes
# Total Time Taken: 26.0 minutes
# Epoch#: 58 completed
# log_iteration: 60/150
# Average time per log_iteration: 26.327385811010995
# Time left = 39.6 minutes
# Total Time Taken: 26.3 minutes
# Epoch#: 59 completed
# log_iteration: 61/150
# Average time per log_iteration: 26.330868220720134
# Time left = 39.0 minutes
# Total Time Taken: 26.8 minutes
# Epoch#: 60 completed
# log_iteration: 62/150
# Average time per log_iteration: 26.311572305617794
# Time left = 38.4 minutes
# Total Time Taken: 27.2 minutes
# Epoch#: 61 completed
# log_iteration: 63/150
# Average time per log_iteration: 26.291413696985398
# Time left = 38.4 minutes
# Total Time Taken: 27.6 minutes
# Epoch#: 62 completed
# log_iteration: 64/150
# Average time per log_iteration: 26.283885300159454
# Time left = 37.8 minutes
# Total Time Taken: 28.0 minutes
# Epoch#: 63 completed
# log_iteration: 65/150
# Average time per log_iteration: 26.210316129831167
# Time left = 37.2 minutes
# Total Time Taken: 28.4 minutes
# Epoch#: 64 completed
# log_iteration: 66/150
# Average time per log_iteration: 26.138588706652325
# Time left = 36.6 minutes
# Total Time Taken: 28.8 minutes
# Epoch#: 65 completed
# log_iteration: 67/150
# Average time per log_iteration: 26.199298054424684
# Time left = 36.0 minutes
# Total Time Taken: 29.3 minutes
# Epoch#: 66 completed
# log_iteration: 68/150
# Average time per log_iteration: 26.257071687894708
# Time left = 36.0 minutes
# Total Time Taken: 29.8 minutes
# Epoch#: 67 completed
# log_iteration: 69/150
# Average time per log_iteration: 26.188620446384817
# Time left = 35.4 minutes
# Total Time Taken: 30.1 minutes
# Epoch#: 68 completed
# log_iteration: 70/150
# Average time per log_iteration: 26.237737134524753
# Time left = 34.8 minutes
# Total Time Taken: 30.6 minutes
# Epoch#: 69 completed
# log_iteration: 71/150
# Average time per log_iteration: 26.293419048819743
# Time left = 34.8 minutes
# Total Time Taken: 31.1 minutes
# Epoch#: 70 completed
# log_iteration: 72/150
# Average time per log_iteration: 26.290219681130516
# Time left = 34.2 minutes
# Total Time Taken: 31.5 minutes
# Epoch#: 71 completed
# log_iteration: 73/150
# Average time per log_iteration: 26.294803322178044
# Time left = 33.6 minutes
# Total Time Taken: 32.0 minutes
# Epoch#: 72 completed
# log_iteration: 74/150
# Average time per log_iteration: 26.346783025844676
# Time left = 33.6 minutes
# Total Time Taken: 32.5 minutes
# Epoch#: 73 completed
# log_iteration: 75/150
# Average time per log_iteration: 26.331791292826335
# Time left = 33.0 minutes
# Total Time Taken: 32.9 minutes
# Epoch#: 74 completed
# log_iteration: 76/150
# Average time per log_iteration: 26.270054346636723
# Time left = 32.4 minutes
# Total Time Taken: 33.3 minutes
# Epoch#: 75 completed
# log_iteration: 77/150
# Average time per log_iteration: 26.313581311857547
# Time left = 31.8 minutes
# Total Time Taken: 33.8 minutes
# Epoch#: 76 completed
# log_iteration: 78/150
# Average time per log_iteration: 26.309792815110622
# Time left = 31.8 minutes
# Total Time Taken: 34.2 minutes
# Epoch#: 77 completed
# log_iteration: 79/150
# Average time per log_iteration: 26.306247780594646
# Time left = 31.2 minutes
# Total Time Taken: 34.6 minutes
# Epoch#: 78 completed
# log_iteration: 80/150
# Average time per log_iteration: 26.298104628920555
# Time left = 30.6 minutes
# Total Time Taken: 35.1 minutes
# Epoch#: 79 completed
# log_iteration: 81/150
# Average time per log_iteration: 26.2901744518751
# Time left = 30.0 minutes
# Total Time Taken: 35.5 minutes
# Epoch#: 80 completed
# log_iteration: 82/150
# Average time per log_iteration: 26.2374771048383
# Time left = 30.0 minutes
# Total Time Taken: 35.9 minutes
# Epoch#: 81 completed
# log_iteration: 83/150
# Average time per log_iteration: 26.186818642788623
# Time left = 29.4 minutes
# Total Time Taken: 36.2 minutes
# Epoch#: 82 completed
# log_iteration: 84/150
# Average time per log_iteration: 26.22845526252474
# Time left = 28.8 minutes
# Total Time Taken: 36.7 minutes
# Epoch#: 83 completed
# log_iteration: 85/150
# Average time per log_iteration: 26.232834353166467
# Time left = 28.2 minutes
# Total Time Taken: 37.2 minutes
# Epoch#: 84 completed
# log_iteration: 86/150
# Average time per log_iteration: 26.277181023775146
# Time left = 28.2 minutes
# Total Time Taken: 37.7 minutes
# Epoch#: 85 completed
# log_iteration: 87/150
# Average time per log_iteration: 26.314863890066913
# Time left = 27.6 minutes
# Total Time Taken: 38.2 minutes
# Epoch#: 86 completed
# log_iteration: 88/150
# Average time per log_iteration: 26.264159939505838
# Time left = 27.0 minutes
# Total Time Taken: 38.5 minutes
# Epoch#: 87 completed
# log_iteration: 89/150
# Average time per log_iteration: 26.209976314158922
# Time left = 26.4 minutes
# Total Time Taken: 38.9 minutes
# Epoch#: 88 completed
# log_iteration: 90/150
# Average time per log_iteration: 26.254173551665414
# Time left = 26.4 minutes
# Total Time Taken: 39.4 minutes
# Epoch#: 89 completed
# log_iteration: 91/150
# Average time per log_iteration: 26.240677115681407
# Time left = 25.8 minutes
# Total Time Taken: 39.8 minutes
# Epoch#: 90 completed
# log_iteration: 92/150
# Average time per log_iteration: 26.190616776113924
# Time left = 25.2 minutes
# Total Time Taken: 40.2 minutes
# Epoch#: 91 completed
# log_iteration: 93/150
# Average time per log_iteration: 26.189877925380582
# Time left = 24.6 minutes
# Total Time Taken: 40.6 minutes
# Epoch#: 92 completed
# log_iteration: 94/150
# Average time per log_iteration: 26.18263936803696
# Time left = 24.6 minutes
# Total Time Taken: 41.0 minutes
# Epoch#: 93 completed
# log_iteration: 95/150
# Average time per log_iteration: 26.172800992664538
# Time left = 24.0 minutes
# Total Time Taken: 41.4 minutes
# Epoch#: 94 completed
# log_iteration: 96/150
# Average time per log_iteration: 26.167435576518375
# Time left = 23.4 minutes
# Total Time Taken: 41.9 minutes
# Epoch#: 95 completed
# log_iteration: 97/150
# Average time per log_iteration: 26.120243827092278
# Time left = 22.8 minutes
# Total Time Taken: 42.2 minutes
# Epoch#: 96 completed
# log_iteration: 98/150
# Average time per log_iteration: 26.078943213637995
# Time left = 22.8 minutes
# Total Time Taken: 42.6 minutes
# Epoch#: 97 completed
# log_iteration: 99/150
# Average time per log_iteration: 26.12091821371907
# Time left = 22.2 minutes
# Total Time Taken: 43.1 minutes
# Epoch#: 98 completed
# log_iteration: 100/150
# Average time per log_iteration: 26.127517154216765
# Time left = 21.6 minutes
# Total Time Taken: 43.5 minutes
# Epoch#: 99 completed
# log_iteration: 101/150
# Average time per log_iteration: 26.16707675763876
# Time left = 21.6 minutes
# Total Time Taken: 44.0 minutes
# Epoch#: 100 completed
# log_iteration: 102/150
# Average time per log_iteration: 26.20070940840478
# Time left = 21.0 minutes
# Total Time Taken: 44.5 minutes
# Epoch#: 101 completed
# log_iteration: 103/150
# Average time per log_iteration: 26.233813137684052
# Time left = 20.4 minutes
# Total Time Taken: 45.0 minutes
# Epoch#: 102 completed
# log_iteration: 104/150
# Average time per log_iteration: 26.271701014958897
# Time left = 20.4 minutes
# Total Time Taken: 45.5 minutes
# Epoch#: 103 completed
# log_iteration: 105/150
# Average time per log_iteration: 26.264534568786623
# Time left = 19.8 minutes
# Total Time Taken: 46.0 minutes
# Epoch#: 104 completed
# log_iteration: 106/150
# Average time per log_iteration: 26.223222748288567
# Time left = 19.2 minutes
# Total Time Taken: 46.3 minutes
# Epoch#: 105 completed
# log_iteration: 107/150
# Average time per log_iteration: 26.180651098768287
# Time left = 18.6 minutes
# Total Time Taken: 46.7 minutes
# Epoch#: 106 completed
# log_iteration: 108/150
# Average time per log_iteration: 26.14146716506393
# Time left = 18.0 minutes
# Total Time Taken: 47.1 minutes
# Epoch#: 107 completed
# log_iteration: 109/150
# Average time per log_iteration: 26.136576963127204
# Time left = 18.0 minutes
# Total Time Taken: 47.5 minutes
# Epoch#: 108 completed
# log_iteration: 110/150
# Average time per log_iteration: 26.13551467115229
# Time left = 17.4 minutes
# Total Time Taken: 47.9 minutes
# Epoch#: 109 completed
# log_iteration: 111/150
# Average time per log_iteration: 26.09195991679355
# Time left = 16.8 minutes
# Total Time Taken: 48.3 minutes
# Epoch#: 110 completed
# log_iteration: 112/150
# Average time per log_iteration: 26.09219435070242
# Time left = 16.8 minutes
# Total Time Taken: 48.7 minutes
# Epoch#: 111 completed
# log_iteration: 113/150
# Average time per log_iteration: 26.056228437254916
# Time left = 16.2 minutes
# Total Time Taken: 49.1 minutes
# Epoch#: 112 completed
# log_iteration: 114/150
# Average time per log_iteration: 26.014620454687822
# Time left = 15.6 minutes
# Total Time Taken: 49.4 minutes
# Epoch#: 113 completed
# log_iteration: 115/150
# Average time per log_iteration: 26.013651856132174
# Time left = 15.0 minutes
# Total Time Taken: 49.9 minutes
# Epoch#: 114 completed
# log_iteration: 116/150
# Average time per log_iteration: 26.00924007851502
# Time left = 15.0 minutes
# Total Time Taken: 50.3 minutes
# Epoch#: 115 completed
# log_iteration: 117/150
# Average time per log_iteration: 25.998516706319954
# Time left = 14.4 minutes
# Total Time Taken: 50.7 minutes
# Epoch#: 116 completed
# log_iteration: 118/150
# Average time per log_iteration: 25.989023350052914
# Time left = 13.8 minutes
# Total Time Taken: 51.1 minutes
# Epoch#: 117 completed
# log_iteration: 119/150
# Average time per log_iteration: 26.01954030790249
# Time left = 13.2 minutes
# Total Time Taken: 51.6 minutes
# Epoch#: 118 completed
# log_iteration: 120/150
# Average time per log_iteration: 25.984110677242278
# Time left = 13.2 minutes
# Total Time Taken: 52.0 minutes
# Epoch#: 119 completed
# log_iteration: 121/150
# Average time per log_iteration: 26.014727939258922
# Time left = 12.6 minutes
# Total Time Taken: 52.5 minutes
# Epoch#: 120 completed
# log_iteration: 122/150
# Average time per log_iteration: 25.977231762448294
# Time left = 12.0 minutes
# Total Time Taken: 52.8 minutes
# Epoch#: 121 completed
# log_iteration: 123/150
# Average time per log_iteration: 25.969745635986328
# Time left = 11.4 minutes
# Total Time Taken: 53.2 minutes
# Epoch#: 122 completed
# log_iteration: 124/150
# Average time per log_iteration: 26.001463767020933
# Time left = 11.4 minutes
# Total Time Taken: 53.7 minutes
# Epoch#: 123 completed
# log_iteration: 125/150
# Average time per log_iteration: 25.968966381073
# Time left = 10.8 minutes
# Total Time Taken: 54.1 minutes
# Epoch#: 124 completed
# log_iteration: 126/150
# Average time per log_iteration: 25.96859962599618
# Time left = 10.2 minutes
# Total Time Taken: 54.5 minutes
# Epoch#: 125 completed
# log_iteration: 127/150
# Average time per log_iteration: 25.932122198615488
# Time left = 10.2 minutes
# Total Time Taken: 54.9 minutes
# Epoch#: 126 completed
# log_iteration: 128/150
# Average time per log_iteration: 25.924594772979617
# Time left = 9.6 minutes
# Total Time Taken: 55.3 minutes
# Epoch#: 127 completed
# log_iteration: 129/150
# Average time per log_iteration: 25.92790013505507
# Time left = 9.0 minutes
# Total Time Taken: 55.7 minutes
# Epoch#: 128 completed
# log_iteration: 130/150
# Average time per log_iteration: 25.933756910837612
# Time left = 8.4 minutes
# Total Time Taken: 56.2 minutes
# Epoch#: 129 completed
# log_iteration: 131/150
# Average time per log_iteration: 25.939796835411595
# Time left = 8.4 minutes
# Total Time Taken: 56.6 minutes
# Epoch#: 130 completed
# log_iteration: 132/150
# Average time per log_iteration: 25.90569011370341
# Time left = 7.8 minutes
# Total Time Taken: 57.0 minutes
# Epoch#: 131 completed
# log_iteration: 133/150
# Average time per log_iteration: 25.910725953883695
# Time left = 7.2 minutes
# Total Time Taken: 57.4 minutes
# Epoch#: 132 completed
# log_iteration: 134/150
# Average time per log_iteration: 25.938281575245643
# Time left = 7.2 minutes
# Total Time Taken: 57.9 minutes
# Epoch#: 133 completed
# log_iteration: 135/150
# Average time per log_iteration: 25.908185480259082
# Time left = 6.6 minutes
# Total Time Taken: 58.3 minutes
# Epoch#: 134 completed
# log_iteration: 136/150
# Average time per log_iteration: 25.874159911099603
# Time left = 6.0 minutes
# Total Time Taken: 58.6 minutes
# Epoch#: 135 completed
# log_iteration: 137/150
# Average time per log_iteration: 25.845288396751794
# Time left = 5.4 minutes
# Total Time Taken: 59.0 minutes
# Epoch#: 136 completed
# log_iteration: 138/150
# Average time per log_iteration: 25.83781846537106
# Time left = 5.4 minutes
# Total Time Taken: 59.4 minutes
# Epoch#: 137 completed
# log_iteration: 139/150
# Average time per log_iteration: 25.83837906919795
# Time left = 4.8 minutes
# Total Time Taken: 59.9 minutes
# Epoch#: 138 completed
# log_iteration: 140/150
# Average time per log_iteration: 25.86897839818682
# Time left = 4.2 minutes
# Total Time Taken: 60.4 minutes
# Epoch#: 139 completed
# log_iteration: 141/150
# Average time per log_iteration: 25.84018453976787
# Time left = 3.6 minutes
# Total Time Taken: 60.7 minutes
# Epoch#: 140 completed
# log_iteration: 142/150
# Average time per log_iteration: 25.84015119915277
# Time left = 3.6 minutes
# Total Time Taken: 61.2 minutes
# Epoch#: 141 completed
# log_iteration: 143/150
# Average time per log_iteration: 25.86627490036971
# Time left = 3.0 minutes
# Total Time Taken: 61.6 minutes
# Epoch#: 142 completed
# log_iteration: 144/150
# Average time per log_iteration: 25.866329959697193
# Time left = 2.4 minutes
# Total Time Taken: 62.1 minutes
# Epoch#: 143 completed
# log_iteration: 145/150
# Average time per log_iteration: 25.89150183118623
# Time left = 2.4 minutes
# Total Time Taken: 62.6 minutes
# Epoch#: 144 completed
# log_iteration: 146/150
# Average time per log_iteration: 25.893693564689322
# Time left = 1.8 minutes
# Total Time Taken: 63.0 minutes
# Epoch#: 145 completed
# log_iteration: 147/150
# Average time per log_iteration: 25.898469860050955
# Time left = 1.2 minutes
# Total Time Taken: 63.5 minutes
# Epoch#: 146 completed
# log_iteration: 148/150
# Average time per log_iteration: 25.903300792784304
# Time left = 0.6 minutes
# Total Time Taken: 63.9 minutes
# Epoch#: 147 completed
# log_iteration: 149/150
# Average time per log_iteration: 25.90867478735495
# Time left = 0.6 minutes
# Total Time Taken: 64.3 minutes
# Epoch#: 148 completed
# log_iteration: 150/150
# Average time per log_iteration: 25.901991120974223
# Time left = -0.0 minutes
# Total Time Taken: 64.8 minutes
# Epoch#: 149 completed

# %%
# %cd '/home/riz/Insync/rhr407@gmail.com/Google_Drive/PhD/Development/code/Current/Paper_2(v7)/figs/full/GAN/'
# !ls
